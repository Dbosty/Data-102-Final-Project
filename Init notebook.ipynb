# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting pymc3==3.11.5
#   Downloading pymc3-3.11.5-py3-none-any.whl (872 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.2/872.2 KB 18.5 MB/s eta 0:00:00
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: pip in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (22.0.4)
# Requirement already satisfied: dill in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 1)) (0.3.5.1)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 16.5 MB/s eta 0:00:00
# Collecting deprecat
#   Downloading deprecat-2.1.1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: cachetools>=4.2.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 1)) (5.2.0)
# Collecting arviz>=0.11.0
#   Downloading arviz-0.15.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.24.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 1)) (1.2.5)
# Collecting numpy<1.22.2,>=1.15.0
#   Downloading numpy-1.22.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 25.3 MB/s eta 0:00:00
# Collecting scipy<1.8.0,>=1.7.3
#   Downloading scipy-1.7.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.8/39.8 MB 20.1 MB/s eta 0:00:00
# Collecting fastprogress>=0.2.0
#   Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pymc3==3.11.5->-r ./requirements.txt (line 1)) (4.4.0)
# Collecting semver>=2.13.0
#   Downloading semver-3.0.0-py3-none-any.whl (17 kB)
# Collecting theano-pymc==1.1.2
#   Downloading Theano-PyMC-1.1.2.tar.gz (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: filelock in /shared-libs/python3.9/py/lib/python3.9/site-packages (from theano-pymc==1.1.2->pymc3==3.11.5->-r ./requirements.txt (line 1)) (3.8.0)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting h5netcdf>=1.0.2
#   Downloading h5netcdf-1.1.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: packaging in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: matplotlib>=3.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (3.6.0)
# Collecting xarray>=0.21.0
#   Downloading xarray-2023.4.2-py3-none-any.whl (979 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.5/979.5 KB 22.5 MB/s eta 0:00:00
# Collecting setuptools>=60.0.0
#   Downloading setuptools-67.7.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.5 MB/s eta 0:00:00
# Collecting pandas>=0.24.0
#   Downloading pandas-2.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 20.4 MB/s eta 0:00:00
# Collecting arviz>=0.11.0
#   Downloading arviz-0.15.0-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.7 MB/s eta 0:00:00
#   Downloading arviz-0.14.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.3 MB/s eta 0:00:00
# Collecting netcdf4
#   Downloading netCDF4-1.6.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 17.2 MB/s eta 0:00:00
# Collecting arviz>=0.11.0
#   Downloading arviz-0.13.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 11.8 MB/s eta 0:00:00
#   Downloading arviz-0.12.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=38.4 in /root/venv/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (58.1.0)
# Collecting xarray-einstats>=0.2
#   Downloading xarray_einstats-0.5.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.24.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=0.24.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.1->pymc3==3.11.5->-r ./requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from deprecat->pymc3==3.11.5->-r ./requirements.txt (line 1)) (1.14.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.2->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib>=3.2->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.2->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.2->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.2->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib>=3.2->arviz>=0.11.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.24.0->pymc3==3.11.5->-r ./requirements.txt (line 1)) (2022.5)
# Collecting cftime
#   Downloading cftime-1.6.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 26.3 MB/s eta 0:00:00
# Building wheels for collected packages: theano-pymc
#   Building wheel for theano-pymc (setup.py): started
#   Building wheel for theano-pymc (setup.py): finished with status 'done'
#   Created wheel for theano-pymc: filename=Theano_PyMC-1.1.2-py3-none-any.whl size=1529964 sha256=52fe981f5e24da151263d4f87a8aedb65013e5a56edf386c3cce8a947429fa9b
#   Stored in directory: /root/.cache/pip/wheels/04/22/4d/832878ba2fe9ea3543f0189b9288a78e4aa4e0afc851a6890c
# Successfully built theano-pymc
# Installing collected packages: semver, numpy, fastprogress, et-xmlfile, deprecat, scipy, patsy, pandas, openpyxl, cftime, xarray, theano-pymc, netcdf4, xarray-einstats, arviz, pymc3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Not uninstalling numpy at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Not uninstalling scipy at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'scipy'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# Successfully installed arviz-0.12.1 cftime-1.6.2 deprecat-2.1.1 et-xmlfile-1.1.0 fastprogress-1.0.3 netcdf4-1.6.3 numpy-1.22.1 openpyxl-3.1.2 pandas-2.0.1 patsy-0.5.3 pymc3-3.11.5 scipy-1.7.3 semver-3.0.0 theano-pymc-1.1.2 xarray-2023.4.2 xarray-einstats-0.5.1
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d8cd6271-edcb-448c-8086-f68db163b0b9' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
